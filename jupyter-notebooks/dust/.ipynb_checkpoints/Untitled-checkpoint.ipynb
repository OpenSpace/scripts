# %%
#from astropy.table import Table
#t = Table.read('output/done/cloud_catalog.speck')

from astropy.io import ascii
data = ascii.read("_118TAU.speck", data_start=22)
# Out:
# ---------------------------------------------------------------------------
# InconsistentTableError                    Traceback (most recent call last)
# C:\os\local\Anaconda\lib\site-packages\astropy\io\ascii\ui.py in _guess(table, read_kwargs, format, fast_reader)
#     463             reader = get_reader(**read_kwargs)
# --> 464             dat = reader.read(table)
#     465             _read_trace.append({'kwargs': copy.deepcopy(read_kwargs),
#
# C:\os\local\Anaconda\lib\site-packages\astropy\io\ascii\core.py in read(self, table)
#    1195
# -> 1196                     raise InconsistentTableError(errmsg)
#    1197
#
# InconsistentTableError: Number of header columns (3) inconsistent with data columns (53) at data line 0
# Header values: ['datavar', '0', 'color']
# ...

# %%
data
# Out:
# <Table length=1039>
#        col1                col2        ...         col4
#      float64             float64       ...       float64
# ------------------ ------------------- ... --------------------
# 6.4383420076540965  12.025194777468418 ...  0.32091789227300316
#  5.127986943533858  11.329462559916918 ...  0.16951331290331856
# 3.4159040813592108  10.603172313988031 ...  0.03596477929039486
#  6.420035611652706  11.963874050044561 ...  0.08349334982853134
#  3.673156957067315   10.17509657610558 ...   0.4550800049157955
# 2.9291054390706863  10.113246007145237 ... 0.058298020390846375
#   4.38848992543298  10.924241187568358 ...  0.04515864205999659
#  2.890780592860761   9.446005205473782 ...  0.15721139852208696
#  5.718549059532317  11.522747074204561 ... 0.043086411160761416
#  4.744946640953721   11.07240120071038 ...  0.04352591523880894
#                ...                 ... ...                  ...
#  2.981427751547712  -7.681702738738884 ...  0.06900415517107887
# ...
